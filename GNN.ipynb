# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib import cm
import networkx as nx 
# %matplotlib inline
import time
import torch.nn as nn
import random

cuda = True

# %%
train = np.load("./data/loc_train_charged5.npy")

print(train.shape)
print(train[0][:][0][1].shape)
# Out:
# (10000, 49, 2, 5)
# (5,)

# %%
data = train[10]
data = np.transpose(data)
print(data.shape)
maps = [cm.PuRd, cm.YlGn, cm.PuBu, cm.YlOrBr, cm.OrRd]
for part in range(5):
    cmap = maps[part](10*np.arange(49))
    plt.scatter(*data[part], c=cmap)
# Out:
# (5, 2, 49)

# %%
from utils import *
from modules import *

SUFFIX = "_springs5"

train_loader, valid_loader, test_loader, loc_max, loc_min, vel_max, vel_min = load_data(
    64, SUFFIX)

# %%
next(iter(train_loader))[0].shape
# Out:
# torch.Size([64, 5, 49, 4])

# %%
def train(epoch, best_val_loss):
    t = time.time()
    nll_train = []
    acc_train = []
    kl_train = []
    mse_train = []

    model.encoder.train()
    model.decoder.train()
    scheduler.step()
    for batch_idx, (data, relations) in enumerate(train_loader):

        if cuda:
            data, relations = data.cuda(), relations.cuda()
        data, relations = Variable(data), Variable(relations)
        optimizer.zero_grad()

        logits = model.encoder(data, rel_rec, rel_send)
        edges, _ = gumbel_softmax(logits, tau=TAU, hard=HARD, hard_prob=HARD_PROB)
        prob = my_softmax(logits, -1)

        if DECODER_TYPE == 'rnn':
            output = model.decoder(data, edges, rel_rec, rel_send, 100,
                             burn_in=True,
                             burn_in_steps=NUM_TIMESTEPS - PREDICTION_STEPS)
        else:
            output = model.decoder(data, edges, rel_rec, rel_send,
                             PREDICTION_STEPS)

        target = data[:, :, 1:, :]

        loss_nll = nll_gaussian(output, target, VAR)

        if PRIOR:
            loss_kl = kl_categorical(prob, log_prior, NUM_ATOMS)
        else:
            loss_kl = kl_categorical_uniform(prob, NUM_ATOMS,
                                             EDGE_TYPES)

        loss = loss_nll + loss_kl

        acc = edge_accuracy(logits, relations)
        acc_train.append(acc)

        loss.backward()
        optimizer.step()

        mse_train.append(F.mse_loss(output, target).data[0])
        nll_train.append(loss_nll.data[0])
        kl_train.append(loss_kl.data[0])
        
        

    nll_val = []
    acc_val = []
    kl_val = []
    mse_val = []

    model.encoder.eval()
    model.decoder.eval()
    for batch_idx, (data, relations) in enumerate(valid_loader):
        if cuda:
            data, relations = data.cuda(), relations.cuda()
        data, relations = Variable(data, volatile=True), Variable(
            relations, volatile=True)

        logits = model.encoder(data, rel_rec, rel_send)
        edges, _ = gumbel_softmax(logits, tau=TAU, hard=True)
        prob = my_softmax(logits, -1)

        # validation output uses teacher forcing
        output = model.decoder(data, edges, rel_rec, rel_send, 1)

        target = data[:, :, 1:, :]
        loss_nll = nll_gaussian(output, target, VAR)
        loss_kl = kl_categorical_uniform(prob, NUM_ATOMS, EDGE_TYPES)

        acc = edge_accuracy(logits, relations)
        acc_val.append(acc)

        mse_val.append(F.mse_loss(output, target).data[0])
        nll_val.append(loss_nll.data[0])
        kl_val.append(loss_kl.data[0])

    print('Epoch: {:04d}'.format(epoch),
          'nll_train: {:.10f}'.format(np.mean(nll_train)),
          'kl_train: {:.10f}'.format(np.mean(kl_train)),
          'mse_train: {:.10f}'.format(np.mean(mse_train)),
          'acc_train: {:.10f}'.format(np.mean(acc_train)),
          'nll_val: {:.10f}'.format(np.mean(nll_val)),
          'kl_val: {:.10f}'.format(np.mean(kl_val)),
          'mse_val: {:.10f}'.format(np.mean(mse_val)),
          'acc_val: {:.10f}'.format(np.mean(acc_val)),
          'time: {:.4f}s'.format(time.time() - t))
    
    return np.mean(nll_val)


def test():
    acc_test = []
    nll_test = []
    kl_test = []
    mse_test = []
    tot_mse = 0
    counter = 0

    model.encoder.eval()
    model.decoder.eval()

    for batch_idx, (data, relations) in enumerate(test_loader):
        if cuda:
            data, relations = data.cuda(), relations.cuda()
        data, relations = Variable(data, volatile=True), Variable(
            relations, volatile=True)

        assert (data.size(2) - NUM_TIMESTEPS) >= NUM_TIMESTEPS

        data_encoder = data[:, :, :NUM_TIMESTEPS, :].contiguous()
        data_decoder = data[:, :, -NUM_TIMESTEPS:, :].contiguous()

        logits = model.encoder(data_encoder, rel_rec, rel_send)
        edges = gumbel_softmax(logits, tau=TAU, hard=True)

        prob = my_softmax(logits, -1)

        output = model.decoder(data_decoder, edges, rel_rec, rel_send, 1)
        print(output.shape)
        target = data_decoder[:, :, 1:, :]
        loss_nll = nll_gaussian(output, target, VAR)
        loss_kl = kl_categorical_uniform(prob, NUM_ATOMS, EDGE_TYPES)

        acc = edge_accuracy(logits, relations)
        acc_test.append(acc)

        mse_test.append(F.mse_loss(output, target).data[0])
        nll_test.append(loss_nll.data[0])
        kl_test.append(loss_kl.data[0])

        # For plotting purposes
        if DECODER_TYPE == 'rnn':
            if args.dynamic_graph:
                output = model.decoder(data, edges, rel_rec, rel_send, 100,
                                 burn_in=True, burn_in_steps=NUM_TIMESTEPS,
                                 dynamic_graph=True, encoder=model.encoder,
                                 temp=TAU)
            else:
                output = model.decoder(data, edges, rel_rec, rel_send, 100,
                                 burn_in=True, burn_in_steps=NUM_TIMESTEPS)
            output = output[:, :, NUM_TIMESTEPS:, :]
            target = data[:, :, -NUM_TIMESTEPS:, :]
        else:
            data_plot = data[:, :, NUM_TIMESTEPS:NUM_TIMESTEPS + 21,
                        :].contiguous()
            output = model.decoder(data_plot, edges, rel_rec, rel_send, 20)
            target = data_plot[:, :, 1:, :]

        mse = ((target - output) ** 2).mean(dim=0).mean(dim=0).mean(dim=-1)
        tot_mse += mse.data.cpu().numpy()
        counter += 1

    mean_mse = tot_mse / counter
    mse_str = '['
    for mse_step in mean_mse[:-1]:
        mse_str += " {:.12f} ,".format(mse_step)
    mse_str += " {:.12f} ".format(mean_mse[-1])
    mse_str += ']'

    print('--------------------------------')
    print('--------Testing-----------------')
    print('--------------------------------')
    print('nll_test: {:.10f}'.format(np.mean(nll_test)),
          'kl_test: {:.10f}'.format(np.mean(kl_test)),
          'mse_test: {:.10f}'.format(np.mean(mse_test)),
          'acc_test: {:.10f}'.format(np.mean(acc_test)))
    print('MSE: {}'.format(mse_str))

# %%
NUM_EPOCHS = 100
NUM_TIMESTEPS = 49 
dims = 4 
PREDICTION_STEPS = 10
VAR = 5e-5

PRIOR =False


TAU = Variable(torch.FloatTensor([5.]), requires_grad=False).cuda()
HARD = True
HARD_PROB = True

NUM_ATOMS = 5
EDGE_TYPES = 2

DECODER_TYPE = "mlp"

# DECODER_TYPE = "rnn"


DECODER_HIDDEN = 256
SKIP_FIRST = False
DECODER_DROPOUT = 0

off_diag = np.ones([NUM_ATOMS, NUM_ATOMS]) - np.eye(NUM_ATOMS)

rel_rec = np.array(encode_onehot(np.where(off_diag)[1]), dtype=np.float32)
rel_send = np.array(encode_onehot(np.where(off_diag)[0]), dtype=np.float32)

rel_rec = torch.FloatTensor(rel_rec).cuda()
rel_send = torch.FloatTensor(rel_send).cuda()

# %%
# encoder = MLPEncoder(n_in = NUM_TIMESTEPS * 4, n_hid = 256, n_out = 2).cuda()

# decoder = MLPDecoder(n_in_node =4, n_hid = 256, edge_types=2, msg_hid = 256, msg_out=256).cuda()


class GNN(nn.Module):
    def __init__(self):
        super(GNN, self).__init__()


        self.encoder = MLPEncoder(n_in = NUM_TIMESTEPS * 4, n_hid = 256, n_out = 2).cuda()
        
        if DECODER_TYPE == "mlp":
            self.decoder = MLPDecoder(n_in_node =4, n_hid = 256, edge_types=2, msg_hid = 256, msg_out=256).cuda()
        elif DECODER_TYPE == "sim":
            self.decoder = SimulationDecoder(loc_max, loc_min, vel_max, vel_min, SUFFIX).cuda()
        else:
            self.decoder = RNNDecoder(n_in_node=dims,
                         edge_types=EDGE_TYPES,
                         n_hid=DECODER_HIDDEN,
                         do_prob=DECODER_DROPOUT,
                         skip_first=SKIP_FIRST).cuda()
        

    def forward(self, x, tau=1, hard = False, n_samples = 1):

        logits = self.encoder(x, rel_rec, rel_send)
        output = []
        for i in range(n_samples):
            edges = gumbel_softmax(logits, tau=TAU, hard=HARD)
            output.append(self.decoder(x, edges, rel_rec, rel_send,PREDICTION_STEPS))

        return output
    
model = GNN()
model
# Out:
# Using factor graph MLP encoder.
# Using learned interaction net decoder.
# /home/pierre/Documents/DTU/Deep Learning/Project/discrete_flows/GNN/modules.py:27: UserWarning: nn.init.xavier_normal is now deprecated in favor of nn.init.xavier_normal_.
#   nn.init.xavier_normal(m.weight.data)
# /home/pierre/Documents/DTU/Deep Learning/Project/discrete_flows/GNN/modules.py:110: UserWarning: nn.init.xavier_normal is now deprecated in favor of nn.init.xavier_normal_.
#   nn.init.xavier_normal(m.weight.data)
# GNN(
#   (encoder): MLPEncoder(
#     (mlp1): MLP(
#       (fc1): Linear(in_features=196, out_features=256, bias=True)
#       (fc2): Linear(in_features=256, out_features=256, bias=True)
#       (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (mlp2): MLP(
#       (fc1): Linear(in_features=512, out_features=256, bias=True)
#       (fc2): Linear(in_features=256, out_features=256, bias=True)
#       (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (mlp3): MLP(
#       (fc1): Linear(in_features=256, out_features=256, bias=True)
#       (fc2): Linear(in_features=256, out_features=256, bias=True)
#       (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (mlp4): MLP(
#       (fc1): Linear(in_features=768, out_features=256, bias=True)
#       (fc2): Linear(in_features=256, out_features=256, bias=True)
#       (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc_out): Linear(in_features=256, out_features=2, bias=True)
#   )
#   (decoder): MLPDecoder(
#     (msg_fc1): ModuleList(
#       (0): Linear(in_features=8, out_features=256, bias=True)
#       (1): Linear(in_features=8, out_features=256, bias=True)
#     )
#     (msg_fc2): ModuleList(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (out_fc1): Linear(in_features=260, out_features=256, bias=True)
#     (out_fc2): Linear(in_features=256, out_features=256, bias=True)
#     (out_fc3): Linear(in_features=256, out_features=4, bias=True)
#   )
# )

# %%
import torch.optim as optim
from torch.optim import lr_scheduler

optimizer = optim.Adam(list(model.encoder.parameters()) + list(model.decoder.parameters()),lr=5e-4)
scheduler = lr_scheduler.StepLR(optimizer, step_size=200,gamma=0.5)

# %%
t_total = time.time()
best_val_loss = np.inf
best_epoch = 0
for epoch in range(NUM_EPOCHS):
    val_loss = train(epoch, best_val_loss)
    print(TAU)
    TAU = torch.max(TAU * 0.95, torch.FloatTensor([0.5]).cuda())
    
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_epoch = epoch
print("Optimization Finished!")
print("Best Epoch: {:04d}".format(best_epoch))
# Out:
# /home/pierre/Documents/DTU/Deep Learning/Project/discrete_flows/GNN/utils.py:11: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   soft_max_1d = F.softmax(trans_input)
# /home/pierre/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:48: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# /home/pierre/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:49: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# /home/pierre/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:50: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# /home/pierre/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:64: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /home/pierre/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:65: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /home/pierre/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:81: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# /home/pierre/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:82: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# /home/pierre/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:83: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# Epoch: 0000 nll_train: 4188.5698242188 kl_train: -0.7293358445 mse_train: 0.0021815470 acc_train: 0.5064639729 nll_val: 29.9684219360 kl_val: -0.4106457531 mse_val: 0.0000156086 acc_val: 0.5076953125 time: 16.4367s
# tensor([5.], device='cuda:0')
# Epoch: 0001 nll_train: 942.9364013672 kl_train: -0.3666559756 mse_train: 0.0004911126 acc_train: 0.5046924761 nll_val: 24.1210327148 kl_val: -0.3624161780 mse_val: 0.0000125630 acc_val: 0.5029492187 time: 15.1743s
# tensor([4.7500], device='cuda:0')
# Epoch: 0002 nll_train: 850.8153076172 kl_train: -0.3479921818 mse_train: 0.0004431329 acc_train: 0.5010947452 nll_val: 22.9780998230 kl_val: -0.3651160002 mse_val: 0.0000119678 acc_val: 0.4966699219 time: 15.5492s
# tensor([4.5125], device='cuda:0')
# Epoch: 0003 nll_train: 798.4346923828 kl_train: -0.3500539064 mse_train: 0.0004158514 acc_train: 0.4884802946 nll_val: 21.1284904480 kl_val: -0.3727706671 mse_val: 0.0000110044 acc_val: 0.4737402344 time: 15.1822s
# tensor([4.2869], device='cuda:0')
# Epoch: 0004 nll_train: 724.0020751953 kl_train: -0.3644209504 mse_train: 0.0003770844 acc_train: 0.4274382962 nll_val: 19.0905189514 kl_val: -0.3565073609 mse_val: 0.0000099430 acc_val: 0.3831640625 time: 15.2739s
# tensor([4.0725], device='cuda:0')
# Epoch: 0005 nll_train: 625.9639892578 kl_train: -0.3335931003 mse_train: 0.0003260229 acc_train: 0.3374004777 nll_val: 15.9258975983 kl_val: -0.3183419108 mse_val: 0.0000082947 acc_val: 0.3050292969 time: 15.1602s
# tensor([3.8689], device='cuda:0')
# Epoch: 0006 nll_train: 560.4913330078 kl_train: -0.3068948388 mse_train: 0.0002919226 acc_train: 0.2853403662 nll_val: 14.7454948425 kl_val: -0.2985808551 mse_val: 0.0000076799 acc_val: 0.2784765625 time: 15.2221s
# tensor([3.6755], device='cuda:0')
# Epoch: 0007 nll_train: 525.1036987305 kl_train: -0.2904920280 mse_train: 0.0002734915 acc_train: 0.2575189092 nll_val: 13.3415718079 kl_val: -0.2795882225 mse_val: 0.0000069487 acc_val: 0.2396972656 time: 15.1617s
# tensor([3.4917], device='cuda:0')
# Epoch: 0008 nll_train: 497.5305480957 kl_train: -0.2788035274 mse_train: 0.0002591305 acc_train: 0.2347482086 nll_val: 14.9078302383 kl_val: -0.2784954607 mse_val: 0.0000077645 acc_val: 0.2304785156 time: 15.2024s
# tensor([3.3171], device='cuda:0')
# Epoch: 0009 nll_train: 468.2366027832 kl_train: -0.2649438083 mse_train: 0.0002438732 acc_train: 0.2103005573 nll_val: 12.1797361374 kl_val: -0.2797082365 mse_val: 0.0000063436 acc_val: 0.1981738281 time: 15.2076s
# tensor([3.1512], device='cuda:0')
# Epoch: 0010 nll_train: 433.6216125488 kl_train: -0.2557745278 mse_train: 0.0002258446 acc_train: 0.1771048965 nll_val: 10.4928894043 kl_val: -0.2549440861 mse_val: 0.0000054650 acc_val: 0.1559082031 time: 15.1842s
# tensor([2.9937], device='cuda:0')
# Epoch: 0011 nll_train: 379.0425109863 kl_train: -0.2358003110 mse_train: 0.0001974180 acc_train: 0.1200835987 nll_val: 7.1881103516 kl_val: -0.2088420987 mse_val: 0.0000037438 acc_val: 0.0792773438 time: 15.2367s
# tensor([2.8440], device='cuda:0')
# Epoch: 0012 nll_train: 257.3343811035 kl_train: -0.1719012707 mse_train: 0.0001340283 acc_train: 0.0659384952 nll_val: 6.0267257690 kl_val: -0.1766609848 mse_val: 0.0000031389 acc_val: 0.0661132813 time: 15.2222s
# tensor([2.7018], device='cuda:0')
# Epoch: 0013 nll_train: 227.1896362305 kl_train: -0.1564815789 mse_train: 0.0001183279 acc_train: 0.0583648487 nll_val: 5.4793410301 kl_val: -0.1694054604 mse_val: 0.0000028538 acc_val: 0.0634179687 time: 15.2767s
# tensor([2.5667], device='cuda:0')
# Epoch: 0014 nll_train: 195.8117218018 kl_train: -0.1460477859 mse_train: 0.0001019853 acc_train: 0.0525826035 nll_val: 5.5636491776 kl_val: -0.1658886075 mse_val: 0.0000028977 acc_val: 0.0585937500 time: 15.2136s
# tensor([2.4384], device='cuda:0')
# Epoch: 0015 nll_train: 193.6457214355 kl_train: -0.1399506032 mse_train: 0.0001008571 acc_train: 0.0491291799 nll_val: 4.2149324417 kl_val: -0.1535948813 mse_val: 0.0000021953 acc_val: 0.0511132813 time: 15.2223s
# tensor([2.3165], device='cuda:0')
# Epoch: 0016 nll_train: 173.4661102295 kl_train: -0.1345642060 mse_train: 0.0000903469 acc_train: 0.0464570064 nll_val: 4.3090705872 kl_val: -0.1500786692 mse_val: 0.0000022443 acc_val: 0.0489257812 time: 15.2820s
# tensor([2.2006], device='cuda:0')
# Epoch: 0017 nll_train: 159.1629638672 kl_train: -0.1255059242 mse_train: 0.0000828974 acc_train: 0.0424462580 nll_val: 3.6711740494 kl_val: -0.1375132501 mse_val: 0.0000019121 acc_val: 0.0455078125 time: 15.2666s
# tensor([2.0906], device='cuda:0')
# Epoch: 0018 nll_train: 149.2454986572 kl_train: -0.1241800115 mse_train: 0.0000777320 acc_train: 0.0407991640 nll_val: 4.3128175735 kl_val: -0.1394638717 mse_val: 0.0000022463 acc_val: 0.0425683594 time: 15.2343s
# tensor([1.9861], device='cuda:0')
# Epoch: 0019 nll_train: 142.5949859619 kl_train: -0.1169622615 mse_train: 0.0000742682 acc_train: 0.0393312102 nll_val: 4.3428001404 kl_val: -0.1370305270 mse_val: 0.0000022619 acc_val: 0.0493945312 time: 15.2688s
# tensor([1.8868], device='cuda:0')
# Epoch: 0020 nll_train: 124.6668853760 kl_train: -0.1126960963 mse_train: 0.0000649307 acc_train: 0.0370571258 nll_val: 3.5657334328 kl_val: -0.1270664483 mse_val: 0.0000018572 acc_val: 0.0441113281 time: 15.2589s
# tensor([1.7924], device='cuda:0')
# Epoch: 0021 nll_train: 121.2294998169 kl_train: -0.1087600812 mse_train: 0.0000631404 acc_train: 0.0355991242 nll_val: 3.2200706005 kl_val: -0.1257365942 mse_val: 0.0000016771 acc_val: 0.0393847656 time: 15.1957s
# tensor([1.7028], device='cuda:0')
# Epoch: 0022 nll_train: 118.8783111572 kl_train: -0.1068107933 mse_train: 0.0000619158 acc_train: 0.0337927946 nll_val: 3.5629410744 kl_val: -0.1109617949 mse_val: 0.0000018557 acc_val: 0.0358398438 time: 15.2604s
# tensor([1.6177], device='cuda:0')
# Epoch: 0023 nll_train: 113.6129226685 kl_train: -0.1030684039 mse_train: 0.0000591734 acc_train: 0.0340714570 nll_val: 3.7374804020 kl_val: -0.1174574569 mse_val: 0.0000019466 acc_val: 0.0402734375 time: 15.2318s
# tensor([1.5368], device='cuda:0')
# Epoch: 0024 nll_train: 103.4869003296 kl_train: -0.0992112979 mse_train: 0.0000538994 acc_train: 0.0330364252 nll_val: 3.1606507301 kl_val: -0.1140063703 mse_val: 0.0000016462 acc_val: 0.0358105469 time: 15.2505s
# tensor([1.4599], device='cuda:0')
# Epoch: 0025 nll_train: 101.5941467285 kl_train: -0.0993778855 mse_train: 0.0000529136 acc_train: 0.0332902070 nll_val: 3.5524468422 kl_val: -0.1023110449 mse_val: 0.0000018502 acc_val: 0.0396972656 time: 15.2306s
# tensor([1.3869], device='cuda:0')
# Epoch: 0026 nll_train: 95.1722946167 kl_train: -0.0925532058 mse_train: 0.0000495689 acc_train: 0.0313097134 nll_val: 3.5863013268 kl_val: -0.1036910042 mse_val: 0.0000018679 acc_val: 0.0330175781 time: 15.2325s
# tensor([1.3176], device='cuda:0')
# Epoch: 0027 nll_train: 95.0561218262 kl_train: -0.0914383456 mse_train: 0.0000495084 acc_train: 0.0305881768 nll_val: 2.7530839443 kl_val: -0.1004812121 mse_val: 0.0000014339 acc_val: 0.0348828125 time: 15.3167s
# tensor([1.2517], device='cuda:0')
# Epoch: 0028 nll_train: 89.7984542847 kl_train: -0.0913010463 mse_train: 0.0000467700 acc_train: 0.0302597532 nll_val: 2.7927193642 kl_val: -0.0952227414 mse_val: 0.0000014545 acc_val: 0.0331054688 time: 15.2543s
# tensor([1.1891], device='cuda:0')
# Epoch: 0029 nll_train: 80.2688751221 kl_train: -0.0832270905 mse_train: 0.0000418067 acc_train: 0.0278960987 nll_val: 3.1781883240 kl_val: -0.1060576290 mse_val: 0.0000016553 acc_val: 0.0373632813 time: 15.2384s
# tensor([1.1297], device='cuda:0')
# Epoch: 0030 nll_train: 85.9237670898 kl_train: -0.0836156756 mse_train: 0.0000447520 acc_train: 0.0289361067 nll_val: 2.5868086815 kl_val: -0.0929596350 mse_val: 0.0000013473 acc_val: 0.0325976563 time: 15.2004s
# tensor([1.0732], device='cuda:0')
# Epoch: 0031 nll_train: 83.2865142822 kl_train: -0.0839183107 mse_train: 0.0000433784 acc_train: 0.0292595541 nll_val: 2.4497554302 kl_val: -0.0868037790 mse_val: 0.0000012759 acc_val: 0.0309667969 time: 15.2527s
# tensor([1.0195], device='cuda:0')
# Epoch: 0032 nll_train: 84.0460510254 kl_train: -0.0830173120 mse_train: 0.0000437740 acc_train: 0.0283539013 nll_val: 3.3024795055 kl_val: -0.0886716247 mse_val: 0.0000017200 acc_val: 0.0337988281 time: 15.2188s
# tensor([0.9686], device='cuda:0')
# Epoch: 0033 nll_train: 75.9870529175 kl_train: -0.0810868666 mse_train: 0.0000395766 acc_train: 0.0274034634 nll_val: 2.5975401402 kl_val: -0.0875838101 mse_val: 0.0000013529 acc_val: 0.0306445313 time: 15.2306s
# tensor([0.9201], device='cuda:0')
# Epoch: 0034 nll_train: 67.9754562378 kl_train: -0.0742718875 mse_train: 0.0000354039 acc_train: 0.0256369427 nll_val: 2.2711889744 kl_val: -0.0870462358 mse_val: 0.0000011829 acc_val: 0.0299804688 time: 15.2201s
# tensor([0.8741], device='cuda:0')
# Epoch: 0035 nll_train: 77.6423187256 kl_train: -0.0807595253 mse_train: 0.0000404387 acc_train: 0.0285877787 nll_val: 3.1362214088 kl_val: -0.0940396339 mse_val: 0.0000016334 acc_val: 0.0347656250 time: 15.4715s
# tensor([0.8304], device='cuda:0')
# Epoch: 0036 nll_train: 72.4004669189 kl_train: -0.0765170902 mse_train: 0.0000377086 acc_train: 0.0273686306 nll_val: 2.6269361973 kl_val: -0.0844027773 mse_val: 0.0000013682 acc_val: 0.0292773437 time: 15.2357s
# tensor([0.7889], device='cuda:0')
# Epoch: 0037 nll_train: 80.1832504272 kl_train: -0.0776269361 mse_train: 0.0000417621 acc_train: 0.0292197452 nll_val: 2.2059521675 kl_val: -0.0837577507 mse_val: 0.0000011489 acc_val: 0.0304492187 time: 15.2114s
# tensor([0.7495], device='cuda:0')
# Epoch: 0038 nll_train: 66.2162017822 kl_train: -0.0723951533 mse_train: 0.0000344876 acc_train: 0.0262490048 nll_val: 2.1008543968 kl_val: -0.0727616996 mse_val: 0.0000010942 acc_val: 0.0295117187 time: 15.2541s
# tensor([0.7120], device='cuda:0')
# Epoch: 0039 nll_train: 71.0402832031 kl_train: -0.0711777285 mse_train: 0.0000370001 acc_train: 0.0265674761 nll_val: 2.2087018490 kl_val: -0.0768649429 mse_val: 0.0000011504 acc_val: 0.0295019531 time: 15.2605s
# tensor([0.6764], device='cuda:0')
# Epoch: 0040 nll_train: 68.1024322510 kl_train: -0.0669074580 mse_train: 0.0000354700 acc_train: 0.0263385748 nll_val: 2.1915287971 kl_val: -0.0738234520 mse_val: 0.0000011414 acc_val: 0.0298828125 time: 15.2385s
# tensor([0.6426], device='cuda:0')
# Epoch: 0041 nll_train: 67.2432937622 kl_train: -0.0668824539 mse_train: 0.0000350225 acc_train: 0.0270949443 nll_val: 2.6550402641 kl_val: -0.0796352476 mse_val: 0.0000013828 acc_val: 0.0341601563 time: 15.2051s
# tensor([0.6104], device='cuda:0')
# Epoch: 0042 nll_train: 69.5917968750 kl_train: -0.0689579993 mse_train: 0.0000362457 acc_train: 0.0271248010 nll_val: 2.5157995224 kl_val: -0.0790618509 mse_val: 0.0000013103 acc_val: 0.0314062500 time: 16.1114s
# tensor([0.5799], device='cuda:0')
# Epoch: 0043 nll_train: 66.3593902588 kl_train: -0.0649646148 mse_train: 0.0000345622 acc_train: 0.0261146497 nll_val: 2.3250095844 kl_val: -0.0745043680 mse_val: 0.0000012109 acc_val: 0.0323437500 time: 15.5540s
# tensor([0.5509], device='cuda:0')
# Epoch: 0044 nll_train: 72.5225677490 kl_train: -0.0670310482 mse_train: 0.0000377722 acc_train: 0.0284683519 nll_val: 2.1809604168 kl_val: -0.0749016628 mse_val: 0.0000011359 acc_val: 0.0327148438 time: 15.2026s
# tensor([0.5234], device='cuda:0')
# Epoch: 0045 nll_train: 74.2834777832 kl_train: -0.0682971627 mse_train: 0.0000386893 acc_train: 0.0285280653 nll_val: 2.1195623875 kl_val: -0.0725552887 mse_val: 0.0000011039 acc_val: 0.0312304688 time: 15.1823s
# tensor([0.5000], device='cuda:0')
# Epoch: 0046 nll_train: 66.0026855469 kl_train: -0.0606177673 mse_train: 0.0000343764 acc_train: 0.0263087182 nll_val: 2.3055920601 kl_val: -0.0692489520 mse_val: 0.0000012008 acc_val: 0.0313867188 time: 15.2165s
# tensor([0.5000], device='cuda:0')
# Epoch: 0047 nll_train: 59.3264389038 kl_train: -0.0564622805 mse_train: 0.0000308992 acc_train: 0.0243531051 nll_val: 2.2386295795 kl_val: -0.0610409640 mse_val: 0.0000011660 acc_val: 0.0308886719 time: 15.2001s
# tensor([0.5000], device='cuda:0')
# Epoch: 0048 nll_train: 60.1059799194 kl_train: -0.0565059930 mse_train: 0.0000313052 acc_train: 0.0248855494 nll_val: 1.8493260145 kl_val: -0.0634813383 mse_val: 0.0000009632 acc_val: 0.0291894531 time: 15.1917s
# tensor([0.5000], device='cuda:0')
# Epoch: 0049 nll_train: 58.9742851257 kl_train: -0.0567360111 mse_train: 0.0000307158 acc_train: 0.0254677548 nll_val: 2.6490778923 kl_val: -0.0707054287 mse_val: 0.0000013797 acc_val: 0.0337304688 time: 15.2011s
# tensor([0.5000], device='cuda:0')
# Epoch: 0050 nll_train: 68.8297042847 kl_train: -0.0583726317 mse_train: 0.0000358488 acc_train: 0.0272591561 nll_val: 2.3376851082 kl_val: -0.0641116276 mse_val: 0.0000012175 acc_val: 0.0324121094 time: 15.2259s
# tensor([0.5000], device='cuda:0')
# Epoch: 0051 nll_train: 49.1901817322 kl_train: -0.0482935384 mse_train: 0.0000256199 acc_train: 0.0222730892 nll_val: 2.9516179562 kl_val: -0.0707858056 mse_val: 0.0000015373 acc_val: 0.0350781250 time: 15.2869s
# tensor([0.5000], device='cuda:0')
# Epoch: 0052 nll_train: 57.8440055847 kl_train: -0.0532943234 mse_train: 0.0000301271 acc_train: 0.0245471736 nll_val: 2.8414180279 kl_val: -0.0718226582 mse_val: 0.0000014799 acc_val: 0.0362500000 time: 15.2427s
# tensor([0.5000], device='cuda:0')
# Epoch: 0053 nll_train: 56.8940773010 kl_train: -0.0506741330 mse_train: 0.0000296323 acc_train: 0.0237012341 nll_val: 1.8753505945 kl_val: -0.0609343387 mse_val: 0.0000009767 acc_val: 0.0279882813 time: 15.2285s
# tensor([0.5000], device='cuda:0')
# Epoch: 0054 nll_train: 61.3153495789 kl_train: -0.0543727390 mse_train: 0.0000319351 acc_train: 0.0254130175 nll_val: 2.3090119362 kl_val: -0.0538700745 mse_val: 0.0000012026 acc_val: 0.0275000000 time: 15.2281s
# tensor([0.5000], device='cuda:0')
# Epoch: 0055 nll_train: 56.6963806152 kl_train: -0.0505695194 mse_train: 0.0000295294 acc_train: 0.0240346338 nll_val: 2.0412497520 kl_val: -0.0606738329 mse_val: 0.0000010632 acc_val: 0.0311132812 time: 15.3276s
# tensor([0.5000], device='cuda:0')
# Epoch: 0056 nll_train: 56.5913810730 kl_train: -0.0498170629 mse_train: 0.0000294747 acc_train: 0.0234375000 nll_val: 1.5293303728 kl_val: -0.0494847149 mse_val: 0.0000007965 acc_val: 0.0235449219 time: 15.3136s
# tensor([0.5000], device='cuda:0')
# Epoch: 0057 nll_train: 55.6193695068 kl_train: -0.0488489196 mse_train: 0.0000289684 acc_train: 0.0233330016 nll_val: 1.9038853645 kl_val: -0.0554444417 mse_val: 0.0000009916 acc_val: 0.0295605469 time: 15.2295s
# tensor([0.5000], device='cuda:0')
# Epoch: 0058 nll_train: 49.3427658081 kl_train: -0.0474057943 mse_train: 0.0000256994 acc_train: 0.0231638137 nll_val: 1.8035943508 kl_val: -0.0555097908 mse_val: 0.0000009394 acc_val: 0.0278027344 time: 15.3133s
# tensor([0.5000], device='cuda:0')
# Epoch: 0059 nll_train: 50.5662307739 kl_train: -0.0484454483 mse_train: 0.0000263366 acc_train: 0.0233081210 nll_val: 1.5364886522 kl_val: -0.0500669032 mse_val: 0.0000008003 acc_val: 0.0248925781 time: 15.3243s
# tensor([0.5000], device='cuda:0')
# Epoch: 0060 nll_train: 46.3293952942 kl_train: -0.0439189672 mse_train: 0.0000241299 acc_train: 0.0206857086 nll_val: 2.0996289253 kl_val: -0.0654373914 mse_val: 0.0000010936 acc_val: 0.0313964844 time: 15.1831s
# tensor([0.5000], device='cuda:0')
# Epoch: 0061 nll_train: 49.6044807434 kl_train: -0.0468899235 mse_train: 0.0000258357 acc_train: 0.0219396895 nll_val: 1.4531247616 kl_val: -0.0480592027 mse_val: 0.0000007568 acc_val: 0.0237890625 time: 15.1745s
# tensor([0.5000], device='cuda:0')
# Epoch: 0062 nll_train: 51.1577339172 kl_train: -0.0479972139 mse_train: 0.0000266447 acc_train: 0.0222382564 nll_val: 2.6078767776 kl_val: -0.0712878257 mse_val: 0.0000013583 acc_val: 0.0362890625 time: 15.1984s
# tensor([0.5000], device='cuda:0')
# Epoch: 0063 nll_train: 47.1108970642 kl_train: -0.0449802056 mse_train: 0.0000245369 acc_train: 0.0212579618 nll_val: 1.6451740265 kl_val: -0.0476529934 mse_val: 0.0000008569 acc_val: 0.0234765625 time: 15.2010s
# tensor([0.5000], device='cuda:0')
# Epoch: 0064 nll_train: 40.6553993225 kl_train: -0.0415780917 mse_train: 0.0000211747 acc_train: 0.0194068471 nll_val: 1.4062845707 kl_val: -0.0485913977 mse_val: 0.0000007324 acc_val: 0.0238476563 time: 15.2170s
# tensor([0.5000], device='cuda:0')
# Epoch: 0065 nll_train: 40.6606216431 kl_train: -0.0413957164 mse_train: 0.0000211774 acc_train: 0.0188594745 nll_val: 1.6162836552 kl_val: -0.0497764014 mse_val: 0.0000008418 acc_val: 0.0244628906 time: 15.2036s
# tensor([0.5000], device='cuda:0')
# Epoch: 0066 nll_train: 48.8481178284 kl_train: -0.0446331985 mse_train: 0.0000254417 acc_train: 0.0213773885 nll_val: 1.9254565239 kl_val: -0.0469734445 mse_val: 0.0000010028 acc_val: 0.0252343750 time: 15.2058s
# tensor([0.5000], device='cuda:0')
# Epoch: 0067 nll_train: 44.9789962769 kl_train: -0.0435154401 mse_train: 0.0000234266 acc_train: 0.0216361465 nll_val: 1.3869009018 kl_val: -0.0435777307 mse_val: 0.0000007223 acc_val: 0.0225781250 time: 15.2875s
# tensor([0.5000], device='cuda:0')
# Epoch: 0068 nll_train: 50.1506690979 kl_train: -0.0442943275 mse_train: 0.0000261201 acc_train: 0.0214570064 nll_val: 1.7455592155 kl_val: -0.0506606586 mse_val: 0.0000009091 acc_val: 0.0248632813 time: 15.1979s
# tensor([0.5000], device='cuda:0')
# Epoch: 0069 nll_train: 43.4569625854 kl_train: -0.0407471806 mse_train: 0.0000226338 acc_train: 0.0203523089 nll_val: 1.7350292206 kl_val: -0.0486426651 mse_val: 0.0000009037 acc_val: 0.0252929687 time: 15.1845s
# tensor([0.5000], device='cuda:0')
# Epoch: 0070 nll_train: 46.5347518921 kl_train: -0.0424867980 mse_train: 0.0000242368 acc_train: 0.0209295382 nll_val: 2.2458949089 kl_val: -0.0597738475 mse_val: 0.0000011697 acc_val: 0.0334179687 time: 15.2140s
# tensor([0.5000], device='cuda:0')
# Epoch: 0071 nll_train: 56.2045059204 kl_train: -0.0473047644 mse_train: 0.0000292732 acc_train: 0.0238455414 nll_val: 1.9065002203 kl_val: -0.0581557117 mse_val: 0.0000009930 acc_val: 0.0286425781 time: 15.2232s
# tensor([0.5000], device='cuda:0')
# Epoch: 0072 nll_train: 41.2498054504 kl_train: -0.0407480821 mse_train: 0.0000214843 acc_train: 0.0194964172 nll_val: 1.3859670162 kl_val: -0.0450705700 mse_val: 0.0000007219 acc_val: 0.0224121094 time: 15.2134s
# tensor([0.5000], device='cuda:0')
# Epoch: 0073 nll_train: 41.4265518188 kl_train: -0.0400415063 mse_train: 0.0000215763 acc_train: 0.0195212978 nll_val: 1.3535450697 kl_val: -0.0437813327 mse_val: 0.0000007050 acc_val: 0.0246289062 time: 15.2734s
# tensor([0.5000], device='cuda:0')
# Epoch: 0074 nll_train: 38.3888168335 kl_train: -0.0377896726 mse_train: 0.0000199942 acc_train: 0.0185410032 nll_val: 1.4774363041 kl_val: -0.0444735140 mse_val: 0.0000007695 acc_val: 0.0244824219 time: 15.5254s
# tensor([0.5000], device='cuda:0')
# Epoch: 0075 nll_train: 43.9308013916 kl_train: -0.0410559177 mse_train: 0.0000228806 acc_train: 0.0202378583 nll_val: 1.6966221333 kl_val: -0.0517158471 mse_val: 0.0000008837 acc_val: 0.0259863281 time: 15.3892s
# tensor([0.5000], device='cuda:0')
# Epoch: 0076 nll_train: 43.9462165833 kl_train: -0.0410751477 mse_train: 0.0000228887 acc_train: 0.0199094347 nll_val: 1.2404093742 kl_val: -0.0419432223 mse_val: 0.0000006460 acc_val: 0.0233789062 time: 15.2388s
# tensor([0.5000], device='cuda:0')
# Epoch: 0077 nll_train: 39.2331275940 kl_train: -0.0381982997 mse_train: 0.0000204339 acc_train: 0.0187798567 nll_val: 1.4341750145 kl_val: -0.0421856605 mse_val: 0.0000007470 acc_val: 0.0219921875 time: 15.1562s
# tensor([0.5000], device='cuda:0')
# Epoch: 0078 nll_train: 44.3012619019 kl_train: -0.0401223041 mse_train: 0.0000230736 acc_train: 0.0203075239 nll_val: 1.4966256618 kl_val: -0.0446309522 mse_val: 0.0000007795 acc_val: 0.0231542969 time: 15.1978s
# tensor([0.5000], device='cuda:0')
# Epoch: 0079 nll_train: 39.8570747375 kl_train: -0.0388937183 mse_train: 0.0000207589 acc_train: 0.0193869427 nll_val: 1.3136746883 kl_val: -0.0378497019 mse_val: 0.0000006842 acc_val: 0.0207519531 time: 15.1952s
# tensor([0.5000], device='cuda:0')
# Epoch: 0080 nll_train: 32.4083023071 kl_train: -0.0335909016 mse_train: 0.0000168793 acc_train: 0.0171128583 nll_val: 1.4554641247 kl_val: -0.0409270488 mse_val: 0.0000007581 acc_val: 0.0225000000 time: 15.1848s
# tensor([0.5000], device='cuda:0')
# Epoch: 0081 nll_train: 34.2018737793 kl_train: -0.0346343257 mse_train: 0.0000178135 acc_train: 0.0165853901 nll_val: 1.8721343279 kl_val: -0.0432762429 mse_val: 0.0000009751 acc_val: 0.0227734375 time: 16.9386s
# tensor([0.5000], device='cuda:0')
# Epoch: 0082 nll_train: 41.2618064880 kl_train: -0.0401264206 mse_train: 0.0000214905 acc_train: 0.0193371815 nll_val: 1.3980624676 kl_val: -0.0422311276 mse_val: 0.0000007282 acc_val: 0.0231542969 time: 15.2604s
# tensor([0.5000], device='cuda:0')
# Epoch: 0083 nll_train: 43.7871971130 kl_train: -0.0385972597 mse_train: 0.0000228058 acc_train: 0.0195859873 nll_val: 1.5277540684 kl_val: -0.0464298800 mse_val: 0.0000007957 acc_val: 0.0241894531 time: 15.2072s
# tensor([0.5000], device='cuda:0')
# Epoch: 0084 nll_train: 39.2186508179 kl_train: -0.0381119475 mse_train: 0.0000204264 acc_train: 0.0187699045 nll_val: 1.6522253752 kl_val: -0.0469878241 mse_val: 0.0000008605 acc_val: 0.0241699219 time: 15.1766s
# tensor([0.5000], device='cuda:0')
# Epoch: 0085 nll_train: 42.0357208252 kl_train: -0.0393316559 mse_train: 0.0000218936 acc_train: 0.0195312500 nll_val: 1.2206099033 kl_val: -0.0407966450 mse_val: 0.0000006357 acc_val: 0.0219628906 time: 15.2337s
# tensor([0.5000], device='cuda:0')
# Epoch: 0086 nll_train: 36.2202491760 kl_train: -0.0355863124 mse_train: 0.0000188647 acc_train: 0.0178343949 nll_val: 1.3090460300 kl_val: -0.0427206457 mse_val: 0.0000006818 acc_val: 0.0226953125 time: 15.1725s
# tensor([0.5000], device='cuda:0')
# Epoch: 0087 nll_train: 32.1082725525 kl_train: -0.0335152932 mse_train: 0.0000167231 acc_train: 0.0164659634 nll_val: 1.7258439064 kl_val: -0.0439538360 mse_val: 0.0000008989 acc_val: 0.0249121094 time: 15.2040s
# tensor([0.5000], device='cuda:0')
# Epoch: 0088 nll_train: 35.5000190735 kl_train: -0.0337112285 mse_train: 0.0000184896 acc_train: 0.0174910430 nll_val: 1.0470006466 kl_val: -0.0356068686 mse_val: 0.0000005453 acc_val: 0.0200878906 time: 15.1931s
# tensor([0.5000], device='cuda:0')
# Epoch: 0089 nll_train: 34.5099334717 kl_train: -0.0339640677 mse_train: 0.0000179739 acc_train: 0.0173616640 nll_val: 1.2631976604 kl_val: -0.0430779010 mse_val: 0.0000006579 acc_val: 0.0221582031 time: 15.1826s
# tensor([0.5000], device='cuda:0')
# Epoch: 0090 nll_train: 33.3281364441 kl_train: -0.0334191099 mse_train: 0.0000173584 acc_train: 0.0166699841 nll_val: 1.2827712297 kl_val: -0.0391064025 mse_val: 0.0000006681 acc_val: 0.0223046875 time: 15.2562s
# tensor([0.5000], device='cuda:0')
# Epoch: 0091 nll_train: 31.7203369141 kl_train: -0.0326686576 mse_train: 0.0000165210 acc_train: 0.0164609873 nll_val: 1.4269472361 kl_val: -0.0370083824 mse_val: 0.0000007432 acc_val: 0.0203515625 time: 15.2315s
# tensor([0.5000], device='cuda:0')
# Epoch: 0092 nll_train: 38.3488922119 kl_train: -0.0342133567 mse_train: 0.0000199734 acc_train: 0.0173069268 nll_val: 1.1198191643 kl_val: -0.0339279398 mse_val: 0.0000005832 acc_val: 0.0187988281 time: 15.2704s
# tensor([0.5000], device='cuda:0')
# Epoch: 0093 nll_train: 35.8788185120 kl_train: -0.0336562768 mse_train: 0.0000186869 acc_train: 0.0178144904 nll_val: 1.8586077690 kl_val: -0.0484183542 mse_val: 0.0000009680 acc_val: 0.0300195312 time: 15.2646s
# tensor([0.5000], device='cuda:0')
# Epoch: 0094 nll_train: 39.3740692139 kl_train: -0.0355712324 mse_train: 0.0000205073 acc_train: 0.0187251194 nll_val: 1.5644783974 kl_val: -0.0450491905 mse_val: 0.0000008148 acc_val: 0.0264550781 time: 16.0096s
# tensor([0.5000], device='cuda:0')
# Epoch: 0095 nll_train: 36.7456321716 kl_train: -0.0331234783 mse_train: 0.0000191384 acc_train: 0.0178493232 nll_val: 1.8305286169 kl_val: -0.0475021936 mse_val: 0.0000009534 acc_val: 0.0262890625 time: 17.4242s
# tensor([0.5000], device='cuda:0')
# Epoch: 0096 nll_train: 38.7646179199 kl_train: -0.0336467102 mse_train: 0.0000201899 acc_train: 0.0186007166 nll_val: 1.4051470757 kl_val: -0.0393857248 mse_val: 0.0000007318 acc_val: 0.0227636719 time: 15.3309s
# tensor([0.5000], device='cuda:0')
# Epoch: 0097 nll_train: 35.6893234253 kl_train: -0.0323208049 mse_train: 0.0000185882 acc_train: 0.0173318073 nll_val: 1.4829771519 kl_val: -0.0390899107 mse_val: 0.0000007724 acc_val: 0.0220898438 time: 15.1651s
# tensor([0.5000], device='cuda:0')
# Epoch: 0098 nll_train: 36.9982032776 kl_train: -0.0338842832 mse_train: 0.0000192699 acc_train: 0.0186703822 nll_val: 2.3128962517 kl_val: -0.0587640107 mse_val: 0.0000012046 acc_val: 0.0322363281 time: 15.3240s
# tensor([0.5000], device='cuda:0')
# Epoch: 0099 nll_train: 37.3760337830 kl_train: -0.0331102349 mse_train: 0.0000194667 acc_train: 0.0180334395 nll_val: 1.0698090792 kl_val: -0.0368781611 mse_val: 0.0000005572 acc_val: 0.0197851562 time: 15.2187s
# tensor([0.5000], device='cuda:0')
# Optimization Finished!
# Best Epoch: 0088

# %%
### Prediction of model with right position at each step


f, axarr = plt.subplots(5, 2, figsize=(15, 30))
batch = next(iter(test_loader))[0][0:5]

model.encoder.eval()
model.decoder.eval()

x = batch.narrow(2,0,49).cuda()
logits = model.encoder(x, rel_rec, rel_send)
edges,_ = gumbel_softmax(logits, tau=TAU, hard=HARD)
prediction = model.decoder(x, edges, rel_rec, rel_send,1)
print(prediction.shape)

maps = [cm.PuRd, cm.YlGn, cm.PuBu, cm.YlOrBr, cm.OrRd]

# maps = ['g', 'b', 'k', 'r', 'c']

for i, ax in enumerate(axarr.flat):
    b = torch.transpose(x[i//2], 1,2)
#     print(b.shape)
    if i%2==0:
        for j in range(5):
            cmap = maps[j](10*np.arange(49))
            ax.scatter(b[j][0], b[j][1], c=cmap)
            
#             cmap = maps[j]
#             ax.scatter(b[j][0], b[j][1], c=cmap, alpha=1)
            

    else:
        
        b = torch.transpose(prediction[i//2], 1,2).cpu().detach().numpy()
#         print(b.shape)
        for j in range(5):
            cmap = maps[j](10*np.arange(48))
            ax.scatter(b[j][0], b[j][1], c=cmap)            
#                 cmap = maps[j]
#                 ax.scatter(b[j][0], b[j][1], c=cmap, alpha = 0.05)
# Out:
# torch.Size([5, 5, 48, 4])

# %%
f, axarr = plt.subplots(5, 2, figsize=(15, 30))
batch = next(iter(test_loader))[0][10:15]

model.encoder.eval()
model.decoder.eval()

pred_steps = 50 
BURN_IN = False
BURN_IN_STEPS = 30
DYNAMIC_GRAPH = False


x = batch.narrow(2,0,49).cuda()
logits = model.encoder(x, rel_rec, rel_send)


edges, _ = gumbel_softmax(logits, tau=TAU*10, hard=HARD)

inputs = batch.transpose(1, 2)


sizes = [edges.size(0), inputs.size(1), edges.size(1),
                 edges.size(2)]
rel_type = edges.unsqueeze(1).expand(sizes)



last_pred = inputs[:, 49::pred_steps, :, :].cuda()
curr_rel_type = rel_type[:, 49::pred_steps, :, :].cuda()
# NOTE: Assumes rel_type is constant (i.e. same across all time steps).


hidden = Variable(torch.zeros(inputs.size(0), inputs.size(2), DECODER_HIDDEN)).cuda()



# Run n prediction steps
preds_list = []
for step in range(0, pred_steps):
    if DECODER_TYPE == "mlp":
        last_pred = model.decoder.single_step_forward(last_pred, rel_rec, rel_send, curr_rel_type)
    elif DECODER_TYPE == "rnn":
        time_steps = inputs.size(1)
        if BURN_IN:
            if step <= BURN_IN_STEPS:
                ins = inputs[:, step, :, :]
            else:
                ins = preds_list[step - 1]
        else:
            assert (pred_steps <= time_steps)
            # Use ground truth trajectory input vs. last prediction
            if not step % pred_steps:
                ins = inputs[:, 49+step, :, :]
            else:
                ins = preds_list[step - 1]

        if DYNAMIC_GRAPH and step >= BURN_IN_STEPS:
            # NOTE: Assumes burn_in_steps = args.timesteps
            logits = model.encoder(
                data[:, :, step - burn_in_steps:step, :].contiguous(),
                rel_rec, rel_send)
            rel_type = gumbel_softmax(logits, tau=temp, hard=True)

        last_pred, hidden = model.decoder.single_step_forward(ins.cuda(), rel_rec, rel_send,
                                                rel_type[:,0,:,:], hidden)

    preds_list.append(last_pred)
if DECODER_TYPE == "rnn":
    
    preds = torch.stack(preds_list, dim=1)

    sizes = [preds.size(0), preds.size(2), preds.size(1), preds.size(3)]
    output = Variable(torch.zeros(sizes)).cuda()
    output = preds.transpose(1,2)
elif DECODER_TYPE == "mlp":
    sizes = [preds_list[0].size(0), preds_list[0].size(1) * pred_steps, preds_list[0].size(2), preds_list[0].size(3)]
    output = Variable(torch.zeros(sizes)).cuda()

    for i in range(len(preds_list)):
        output[:, i::pred_steps, :, :] = preds_list[i]

    output = output.transpose(1,2)

print(output.shape)
# maps = [cm.PuRd, cm.YlGn, cm.PuBu, cm.YlOrBr, cm.OrRd]

maps = ['g', 'b', 'k', 'r', 'c']


for i, ax in enumerate(axarr.flat):
    b = torch.transpose(batch[i//2], 1,2)
#     print(b.shape)
    if i%2==0:
        for j in range(5):
#             cmap = maps[j](10*np.arange(49))
#             ax.scatter(b[j][0], b[j][1], c=cmap)
            
            cmap = maps[j]
            ax.scatter(b[j][0][:49], b[j][1][:49], c=cmap, alpha = 0.2)
            ax.scatter(b[j][0][49:], b[j][1][49:], c=cmap, alpha = 1)
            

    else:
        
        b = torch.transpose(batch[i//2], 1,2).cpu().detach().numpy()
        d = torch.transpose(output[i//2], 1,2).cpu().detach().numpy()

        for j in range(5):
#             cmap = maps[j](10*np.arange(48))
#             ax.scatter(b[j][0], b[j][1], c=cmap)  

            cmap = maps[j]
            ax.scatter(b[j][0][:49], b[j][1][:49], c=cmap, alpha = 0.2)
            ax.scatter(d[j][0], d[j][1], c=cmap, alpha = 1)
# Out:
# torch.Size([5, 5, 50, 4])

# %%
example_num = 2


if DECODER_TYPE== "mlp":
    f, axarr = plt.subplots(5, 4, figsize=(16, 16))
    batch_complete_data = next(iter(test_loader))
    batch = batch_complete_data[0][5*example_num:5*(example_num+1)]
    edges_b = batch_complete_data[1][5*example_num:5*(example_num+1)]
    batch_edges = edges_b.view((5,5,4)).numpy()

    model.encoder.eval()
    model.decoder.eval()

    pred_steps = 50 

    n_samples = 50

    x = batch.narrow(2,0,49).cuda()
    # logits = torch.clamp(model.encoder(x, rel_rec, rel_send),0.1,0.9)
    logits = model.encoder(x, rel_rec, rel_send)


    inputs = batch.transpose(1, 2)
    outputs_list = []
    edges_samples = []
    probs_samples = []
    for sample in range(n_samples):
    #     edges = torch.clamp(gumbel_softmax(logits, tau=TAU, hard=HARD),0.2,0.8)
        edges, probs = gumbel_softmax(logits, tau=TAU*10, hard=True, hard_prob=True)
        sizes = [edges.size(0), inputs.size(1), edges.size(1),
                     edges.size(2)]
        rel_type = edges.unsqueeze(1).expand(sizes)



        last_pred = inputs[:, 49::pred_steps, :, :].cuda()
        curr_rel_type = rel_type[:, 49::pred_steps, :, :].cuda()
        # NOTE: Assumes rel_type is constant (i.e. same across all time steps).


        # Run n prediction steps
        preds = []
        for step in range(0, pred_steps):
            last_pred = model.decoder.single_step_forward(last_pred, rel_rec, rel_send, curr_rel_type)
            preds.append(last_pred)
            
        sizes = [preds[0].size(0), preds[0].size(1) * pred_steps, preds[0].size(2), preds[0].size(3)]

        output = Variable(torch.zeros(sizes))
        if inputs.is_cuda:
            output = output.cuda()

        for i in range(len(preds)):
            output[:, i::pred_steps, :, :] = preds[i]

        output = output.transpose(1,2)
        outputs_list.append(output.cpu().detach())
        edges_samples.append(edges.cpu().detach())
        probs_samples.append(probs.cpu().detach())

    # maps = [cm.PuRd, cm.YlGn, cm.PuBu, cm.YlOrBr, cm.OrRd]

    maps = ['g', 'b', 'k', 'r', 'c']

    x_lim = []
    y_lim = []


    for i, ax in enumerate(axarr.flat):
        b = torch.transpose(batch[i//4], 1,2)
    #     print(b.shape)
        if i%4 ==0:

            edges_list = []

            for k,part in enumerate(batch_edges[i//4]):
                l = np.insert(part,k,0)
                edges_list.append(np.array(l))

            edges_list = np.array(edges_list)

            graph = nx.Graph()
            if SUFFIX == "_springs5":
                graph = nx.from_numpy_matrix(edges_list)
                type_edges = [edges_list[a][b] for (a,b) in graph.edges()]
                nx.draw(graph,
                        ax=ax, 
                        pos=nx.shell_layout(graph),
                        node_color=maps, 
                        edge_color=type_edges,
                        width = 3)
            elif SUFFIX == "_charged5":
                edges_list[edges_list == 0] = -1
                edges_list = edges_list + np.eye(edges_list.shape[0])
                graph = nx.from_numpy_matrix(edges_list)
                type_edges = [edges_list[a][b] for (a,b) in graph.edges()]

                nx.draw(graph,
                        ax=ax, 
                        pos=nx.shell_layout(graph),
                        node_color=maps,
                        edge_cmap=cm.bwr, 
                        edge_color=type_edges,
                        width = 3)

        elif i%4==1:
            for j in range(5):
                cmap = maps[j]
                ax.scatter(b[j][0][:49], b[j][1][:49], c=cmap, alpha = 0.2)
                ax.scatter(b[j][0][49:], b[j][1][49:], c=cmap, alpha = 1)
                x_lim = ax.get_xlim()
                y_lim = ax.get_ylim()


        elif i%4==2:

            b = torch.transpose(batch[i//4], 1,2).cpu().detach().numpy()
            for j in range(5):
                cmap = maps[j]
                #ax.scatter(b[j][0][:49], b[j][1][:49], c=cmap, alpha = 0.2)
            for output in outputs_list:
                d = torch.transpose(output[i//4], 1,2).numpy()
                for j in range(5):
                    cmap = maps[j]
                    ax.scatter(d[j][0], d[j][1], c=cmap, alpha = 0.1)
                    ax.set_xlim(x_lim)
                    ax.set_ylim(y_lim) 
        else:
            edges_list = []
            resized_edges = probs_samples[random.randint(0,n_samples-1)].narrow(-1,0,1) #show the graph of a random sample
            for k,part in enumerate(resized_edges.view(5,5,4,-1).numpy()[i//4]):
                l = np.insert(part,k,0)
                edges_list.append(np.array(l))

            edges_list = np.array(edges_list)
            if SUFFIX == "_springs5":
                graph = nx.Graph()
                graph = nx.from_numpy_matrix(edges_list)
                proba_edges = [edges_list[a][b] for (a,b) in graph.edges()]
                nx.draw(graph, 
                        ax=ax, 
                        pos=nx.shell_layout(graph), 
                        node_color=maps, 
                        edge_cmap=cm.Blues, 
                        edge_color=proba_edges,
                        edge_vmin=0, 
                        edge_vmax=1,
                        width = 3)
            else:
                graph = nx.Graph()
                edges_list[edges_list == 0] = 1e-5
                edges_list = edges_list + np.eye(edges_list.shape[0])

                graph = nx.from_numpy_matrix(edges_list)
                proba_edges = [edges_list[a][b] for (a,b) in graph.edges()]

                nx.draw(graph, 
                        ax=ax, 
                        pos=nx.shell_layout(graph), 
                        node_color=maps, 
                        edge_cmap=cm.bwr, 
                        edge_vmin=0, 
                        edge_vmax=1,
                        edge_color=proba_edges,
                        width = 3)



plt.savefig("test_predictions_tau5_0.png", dpi = 500)

# %%
if DECODER_TYPE== "rnn":
    f, axarr = plt.subplots(5, 4, figsize=(15, 15))
    batch_complete_data = next(iter(test_loader))
    batch = batch_complete_data[0][10:15]
    edges_b = batch_complete_data[1][10:15]
    batch_edges = edges_b.view((5,5,4)).numpy()

    model.encoder.eval()
    model.decoder.eval()

    pred_steps = 50 

    n_samples = 50

    x = batch.narrow(2,0,49).cuda()
    # logits = torch.clamp(model.encoder(x, rel_rec, rel_send),0.1,0.9)
    logits = model.encoder(x, rel_rec, rel_send)


    inputs = batch.transpose(1, 2)
    outputs_list = []
    edges_samples = []
    for sample in range(n_samples):
    #     edges = torch.clamp(gumbel_softmax(logits, tau=TAU, hard=HARD),0.2,0.8)
        edges = gumbel_softmax(logits, tau=TAU*10, hard=True, hard_prob=True)

        sizes = [edges.size(0), inputs.size(1), edges.size(1),
                     edges.size(2)]
        
        
              
        rel_type = edges.unsqueeze(1).expand(sizes)

        hidden = Variable(torch.zeros(inputs.size(0), inputs.size(2), DECODER_HIDDEN)).cuda()

        last_pred = inputs[:, 49::pred_steps, :, :].cuda()
        curr_rel_type = rel_type[:, 49::pred_steps, :, :].cuda()
        # NOTE: Assumes rel_type is constant (i.e. same across all time steps).


        # Run n prediction steps
        preds = []
        for step in range(0, pred_steps):
            time_steps = inputs.size(1)
            if BURN_IN:
                if step <= BURN_IN_STEPS:
                    ins = inputs[:, step, :, :]
                else:
                    
                    ins = preds[step - 1]
            else:
                assert (pred_steps <= time_steps)
                # Use ground truth trajectory input vs. last prediction
                if not step % pred_steps:
                    ins = inputs[:, 49+step, :, :]
                else:
                    ins = preds[step - 1]

            if DYNAMIC_GRAPH and step >= BURN_IN_STEPS:
                # NOTE: Assumes burn_in_steps = args.timesteps
                logits = model.encoder(
                    data[:, :, step - burn_in_steps:step, :].contiguous(),
                    rel_rec, rel_send)
                rel_type = gumbel_softmax(logits, tau=temp, hard=False)

            last_pred, hidden = model.decoder.single_step_forward(ins.cuda(), rel_rec, rel_send,
                                                rel_type[:,0,:,:], hidden)
            preds.append(last_pred)

        
  
        sizes = [preds[0].size(0), pred_steps, preds[0].size(1), preds[0].size(2)]

        output = Variable(torch.zeros(sizes))
        if inputs.is_cuda:
            output = output.cuda()

        for i in range(len(preds)):
            output[:, i::pred_steps, :, :] = preds[i].unsqueeze_(1)

        output = output.transpose(1,2)
        outputs_list.append(output.cpu().detach())
        edges_samples.append(edges.cpu().detach())

    # maps = [cm.PuRd, cm.YlGn, cm.PuBu, cm.YlOrBr, cm.OrRd]

    maps = ['g', 'b', 'k', 'r', 'c']

    x_lim = []
    y_lim = []


    for i, ax in enumerate(axarr.flat):
        b = torch.transpose(batch[i//4], 1,2)
    #     print(b.shape)
        if i%4 ==0:

            edges_list = []

            for k,part in enumerate(batch_edges[i//4]):
                l = np.insert(part,k,0)
                edges_list.append(np.array(l))

            edges_list = np.array(edges_list)

            graph = nx.Graph()
            if SUFFIX == "_springs5":
                graph = nx.from_numpy_matrix(edges_list)
                type_edges = [edges_list[a][b] for (a,b) in graph.edges()]
                nx.draw(graph,
                        ax=ax, 
                        pos=nx.shell_layout(graph),
                        node_color=maps, 
                        edge_color=type_edges,
                        width = 3)
            elif SUFFIX == "_charged5":
                edges_list[edges_list == 0] = -1
                edges_list = edges_list + np.eye(edges_list.shape[0])
                graph = nx.from_numpy_matrix(edges_list)
                type_edges = [edges_list[a][b] for (a,b) in graph.edges()]

                nx.draw(graph,
                        ax=ax, 
                        pos=nx.shell_layout(graph),
                        node_color=maps,
                        edge_cmap=cm.bwr, 
                        edge_color=type_edges,
                        width = 3)

        elif i%4==1:
            for j in range(5):
                cmap = maps[j]
                ax.scatter(b[j][0][:49], b[j][1][:49], c=cmap, alpha = 0.2)
                ax.scatter(b[j][0][49:], b[j][1][49:], c=cmap, alpha = 1)
                x_lim = ax.get_xlim()
                y_lim = ax.get_ylim()


        elif i%4==2:

            b = torch.transpose(batch[i//4], 1,2).cpu().detach().numpy()
            for j in range(5):
                cmap = maps[j]
                #ax.scatter(b[j][0][:49], b[j][1][:49], c=cmap, alpha = 0.2)
            for output in outputs_list:
                d = torch.transpose(output[i//4], 1,2).numpy()
                for j in range(5):
                    cmap = maps[j]
                    ax.scatter(d[j][0], d[j][1], c=cmap, alpha = 0.1)
                    ax.set_xlim(x_lim)
                    ax.set_ylim(y_lim) 
        else:
            edges_list = []
            resized_edges = edges_samples[random.randint(0,n_samples-1)].narrow(-1,0,1) #show the graph of a random sample
            for k,part in enumerate(resized_edges.view(5,5,4,-1).numpy()[i//4]):
                l = np.insert(part,k,0)
                edges_list.append(np.array(l))

            edges_list = np.array(edges_list)
            if SUFFIX == "_springs5":
                graph = nx.Graph()
                graph = nx.from_numpy_matrix(edges_list)
                proba_edges = [edges_list[a][b] for (a,b) in graph.edges()]
                nx.draw(graph, 
                        ax=ax, 
                        pos=nx.shell_layout(graph), 
                        node_color=maps, 
                        edge_cmap=cm.Blues, 
                        edge_color=proba_edges,
                        edge_vmin=0, 
                        edge_vmax=1,
                        width = 3)
            else:
                graph = nx.Graph()
                edges_list[edges_list == 0] = 1e-5
                edges_list = edges_list + np.eye(edges_list.shape[0])

                graph = nx.from_numpy_matrix(edges_list)
                proba_edges = [edges_list[a][b] for (a,b) in graph.edges()]

                nx.draw(graph, 
                        ax=ax, 
                        pos=nx.shell_layout(graph), 
                        node_color=maps, 
                        edge_cmap=cm.bwr, 
                        edge_vmin=0, 
                        edge_vmax=1,
                        edge_color=proba_edges,
                        width = 3)

# %%
from utils import *
from modules import *


edges_samples = []

for sample in range(n_samples):
    edges = gumbel_softmax(logits, tau=TAU*10, hard=True, hard_prob = True)

    edges_samples.append(edges.cpu().detach())


f, axarr = plt.subplots(10, 5, figsize=(15, 25))
for i, ax in enumerate(axarr.flat):
    
    edges_list = []
    resized_edges = edges_samples[i].narrow(-1,0,1) #show the graph of a random sample
    for k,part in enumerate(resized_edges.view(5,5,4,-1).numpy()[4]):
        l = np.insert(part,k,0)
        edges_list.append(np.array(l))
    edges_list = np.array(edges_list)
    graph = nx.Graph()
    edges_list[edges_list == 0] = 1e-5
    edges_list = edges_list + np.eye(edges_list.shape[0])
#     print(edges_list)
    graph = nx.from_numpy_matrix(edges_list)
    proba_edges = [edges_list[a][b] for (a,b) in graph.edges()]
#     print(proba_edges)
    if SUFFIX == "_springs5":
        graph = nx.Graph()
        graph = nx.from_numpy_matrix(edges_list)
        proba_edges = [edges_list[a][b] for (a,b) in graph.edges()]
        nx.draw(graph, 
                ax=ax, 
                pos=nx.shell_layout(graph), 
                node_color=maps, 
                edge_cmap=cm.Blues, 
                edge_color=proba_edges,
                edge_vmin=0, 
                edge_vmax=1,
                width = 3)
    else:
        graph = nx.Graph()
        edges_list[edges_list == 0] = 1e-5
        edges_list = edges_list + np.eye(edges_list.shape[0])

        graph = nx.from_numpy_matrix(edges_list)
        proba_edges = [edges_list[a][b] for (a,b) in graph.edges()]

        nx.draw(graph, 
                ax=ax, 
                pos=nx.shell_layout(graph), 
                node_color=maps, 
                edge_cmap=cm.bwr, 
                edge_vmin=0, 
                edge_vmax=1,
                edge_color=proba_edges,
                width = 3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-2e9abdb7d946> in <module>
#       8     edges = gumbel_softmax(logits, tau=TAU*10, hard=True, hard_prob = True)
#       9
# ---> 10     edges_samples.append(edges.cpu().detach())
#      11
#      12
#
# AttributeError: 'tuple' object has no attribute 'cpu'
